# %%
def findtille():

    while True:

        try:
            number = int(input("Till what place do you want the value of epsilon not"))
        except:
            print("This is not a valid integer")
            continue
        else:
            calc_val = round(19/7,number)
            break
    print("The value of epsilon till the decimal place {} is {}".format(number,calc_val))

# %%
findtille()
# Out:
# Till what place do you want the value of epsilon not not
# This is not a valid integer
# Till what place do you want the value of epsilon not 10
# The value of epsilon till the decimal place 10 is 2.7142857143
