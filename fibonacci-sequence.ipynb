# %%
def fibonacci():

    while True:
        try:
            till = int(input("Till what number do you want the fibonacci sequence"))
        except:
            print("That is not a valid integer")
            continue
        else:
            a,b = 0,1
            for i in range(0,till):
                a,b = b , a+b
            
                
            break
    print(a,b)

# %%
fibonacci()
# Out:
# Till what number do you want the fibonacci sequence 10
# 55 89
